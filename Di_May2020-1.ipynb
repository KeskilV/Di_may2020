# %% [markdown]
# ## Рисуем параболу
#
#
# Пусть  $X$ -
#
#  Формула баллистики:
# $$ x(t) = x_{0} + v_{x} t$$
# $$ y(t) = y_{0} + v_{y} t - \frac{g t^2}{2}$$

# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
import math
import ipywidgets as widgets
import numpy as np
#from IPython.display import display
global A,S,Distance,H 
fig, ax = plt.subplots(1, figsize=(10, 5))



def update_XY_np(angle, v):
    global A,S,Distance,H 
    t = np.linspace(0,100,1000) 
    g = 9.8
    X = v*np.cos(angle*math.pi/180)*t
    Y = v*np.sin(angle*math.pi/180)*t - (g*t**2)/2
    A,S,Distance,H   = angle, v, max(X), max(Y)
    return X,Y

def update_XY(angle, v):
    global A,S,Distance,H 
    X,Y = [],[]
    g = 9.8
    x = 0
    y = 0
    t = 0
    while y>=0:
        X.append(x)
        Y.append(y)
        t += 0.1
        x = v*math.cos(angle*math.pi/180)*t
        y = v*math.sin(angle*math.pi/180)*t - (g*t**2)/2
    A,S,Distance,H   = angle, v, X[-1], max(Y)
    return X,Y

def update_plot(angle, v):
    #ax.clear()
    X,Y = update_XY_np(angle, v)
     
    #ax.scatter(X, Y,s=5)  
    ax.plot(X, Y, label = "angle = {:.1f} speed = {:.1f} distance = {:.1f}".format(angle,v,X[-1]))
    ax.set_ylim(0, max(X)//2)
    ax.set_xlim(0, max(X)*1.05)
    ax.legend(loc=1)
    ax.set_xlabel('distance')
    plt.show()

    


def on_button_clicked(b): # Описываем обработчик события
    ax.clear()
    

def on_button_clicked2(b): # Описываем обработчик события
    print('angle {:.1f} speed {:.1f} distance {:.1f} highest {:.1f}'.format(A,S,Distance,H ))
    
    
    
button1 = widgets.Button(description="Clear", button_style='warning') # 'success', 'info', 'warning', 'danger', '')                       )
button2 = widgets.Button(description="record", button_style='success') # 'success', 'info', 'warning', 'danger', '')                        ) 
button1.on_click(on_button_clicked) # Назначаем этот обработчик на событие "on_click"
button2.on_click(on_button_clicked2)
display(button1,button2) # Отображаем кнопку
                         
angle = widgets.FloatSlider(min=0, max=90, value=45, description='angle:')
v = widgets.FloatSlider(min=0, max=200, value=10, description='V:')
widgets.interactive(update_plot, angle=angle, v=v)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Button(button_style='warning', description='Clear', style=ButtonStyle())
# Button(button_style='success', description='record', style=ButtonStyle())
# interactive(children=(FloatSlider(value=45.0, description='angle:', max=90.0), FloatSlider(value=10.0, description='V:', max=200.0), Output()), _dom_classes=('widget-interact',))
# angle 45.0 speed 186.0 distance 13152.2 highest 882.6
# angle 45.0 speed 100.8 distance 7127.6 highest 259.2
# angle 65.5 speed 100.8 distance 4180.1 highest 429.2
# angle 65.5 speed 130.4 distance 5407.6 highest 718.4
# angle 65.5 speed 192.5 distance 7982.8 highest 1565.5

# %%
ax.clear()

# %%
X
# Out:
# [0,
#  0.7071067811865476,
#  1.4142135623730951,
#  2.121320343559643,
#  2.8284271247461903,
#  3.5355339059327378,
#  4.242640687119285,
#  4.949747468305833,
#  5.65685424949238,
#  6.363961030678928,
#  7.071067811865475,
#  7.7781745930520225,
#  8.48528137423857,
#  9.19238815542512,
#  9.899494936611667]

# %%
import numpy as np
import matplotlib.pyplot as plt
tt = np.linspace(0,10,100)
x = 12 * tt
y = 20*tt - 14*tt**2
fig,ax = plt.subplots()
help (ax)
ax.scatter(x,y,s=1,c='Green')

#print(type(ax))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Help on AxesSubplot in module matplotlib.axes._subplots object:
#
# class AxesSubplot(SubplotBase, matplotlib.axes._axes.Axes)
#  |  Base class for subplots, which are :class:`Axes` instances with
#  |  additional methods to facilitate generating and manipulating a set
#  |  of :class:`Axes` within a figure.
#  |
#  |  Method resolution order:
#  |      AxesSubplot
#  |      SubplotBase
#  |      matplotlib.axes._axes.Axes
#  |      matplotlib.axes._base._AxesBase
#  |      matplotlib.artist.Artist
#  |      builtins.object
#  |
#  |  Methods inherited from SubplotBase:
#  |
#  |  __init__(self, fig, *args, **kwargs)
#  |      *fig* is a :class:`matplotlib.figure.Figure` instance.
#  |
#  |      *args* is the tuple (*numRows*, *numCols*, *plotNum*), where
#  |      the array of subplots in the figure has dimensions *numRows*,
#  |      *numCols*, and where *plotNum* is the number of the subplot
# ...
